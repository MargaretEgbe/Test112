# %%
import requests
import time

while True:
    r = requests.get("https://api.openbrewerydb.org/v1/breweries")
    if r.status_code==200:
        data = r.json()
        print(data)
        time.sleep(60)
        
    else:
        exit()
# Out:
# [{'id': '5128df48-79fc-4f0f-8b52-d06be54d0cec', 'name': '(405) Brewing Co', 'brewery_type': 'micro', 'address_1': '1716 Topeka St', 'address_2': None, 'address_3': None, 'city': 'Norman', 'state_province': 'Oklahoma', 'postal_code': '73069-8224', 'country': 'United States', 'longitude': '-97.46818222', 'latitude': '35.25738891', 'phone': '4058160490', 'website_url': 'http://www.405brewing.com', 'state': 'Oklahoma', 'street': '1716 Topeka St'}, {'id': '9c5a66c8-cc13-416f-a5d9-0a769c87d318', 'name': '(512) Brewing Co', 'brewery_type': 'micro', 'address_1': '407 Radam Ln Ste F200', 'address_2': None, 'address_3': None, 'city': 'Austin', 'state_province': 'Texas', 'postal_code': '78745-1197', 'country': 'United States', 'longitude': None, 'latitude': None, 'phone': '5129211545', 'website_url': 'http://www.512brewing.com', 'state': 'Texas', 'street': '407 Radam Ln Ste F200'}, {'id': '34e8c68b-6146-453f-a4b9-1f6cd99a5ada', 'name': '1 of Us Brewing Company', 'brewery_type': 'micro', 'address_1': '8100 Washington Ave', 'address_2': None, 'address_3': None, 'city': 'Mount Pleasant', 'state_province': 'Wisconsin', 'postal_code': '53406-3920', 'country': 'United States', 'longitude': '-87.88336350209435', 'latitude': '42.72010826899558', 'phone': '2624847553', 'website_url': 'https://www.1ofusbrewing.com', 'state': 'Wisconsin', 'street': '8100 Washington Ave'}, {'id': 'ef970757-fe42-416f-931d-722451f1f59c', 'name': '10 Barrel Brewing Co', 'brewery_type': 'large', 'address_1': '1501 E St', 'address_2': None, 'address_3': None, 'city': 'San Diego', 'state_province': 'California', 'postal_code': '92101-6618', 'country': 'United States', 'longitude': '-117.129593', 'latitude': '32.714813', 'phone': '6195782311', 'website_url': 'http://10barrel.com', 'state': 'California', 'street': '1501 E St'}, {'id': '6d14b220-8926-4521-8d19-b98a2d6ec3db', 'name': '10 Barrel Brewing Co', 'brewery_type': 'large', 'address_1': '62970 18th St', 'address_2': None, 'address_3': None, 'city': 'Bend', 'state_province': 'Oregon', 'postal_code': '97701-9847', 'country': 'United States', 'longitude': '-121.281706', 'latitude': '44.08683531', 'phone': '5415851007', 'website_url': 'http://www.10barrel.com', 'state': 'Oregon', 'street': '62970 18th St'}, {'id': 'e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2', 'name': '10 Barrel Brewing Co', 'brewery_type': 'large', 'address_1': '1135 NW Galveston Ave Ste B', 'address_2': None, 'address_3': None, 'city': 'Bend', 'state_province': 'Oregon', 'postal_code': '97703-2465', 'country': 'United States', 'longitude': '-121.3288021', 'latitude': '44.0575649', 'phone': '5415851007', 'website_url': None, 'state': 'Oregon', 'street': '1135 NW Galveston Ave Ste B'}, {'id': 'e432899b-7f58-455f-9c7b-9a6e2130a1e0', 'name': '10 Barrel Brewing Co', 'brewery_type': 'large', 'address_1': '1411 NW Flanders St', 'address_2': None, 'address_3': None, 'city': 'Portland', 'state_province': 'Oregon', 'postal_code': '97209-2620', 'country': 'United States', 'longitude': '-122.6855056', 'latitude': '45.5259786', 'phone': '5032241700', 'website_url': 'http://www.10barrel.com', 'state': 'Oregon', 'street': '1411 NW Flanders St'}, {'id': '9f1852da-c312-42da-9a31-097bac81c4c0', 'name': '10 Barrel Brewing Co - Bend Pub', 'brewery_type': 'large', 'address_1': '62950 NE 18th St', 'address_2': None, 'address_3': None, 'city': 'Bend', 'state_province': 'Oregon', 'postal_code': '97701', 'country': 'United States', 'longitude': '-121.2809536', 'latitude': '44.0912109', 'phone': '5415851007', 'website_url': None, 'state': 'Oregon', 'street': '62950 NE 18th St'}, {'id': 'ea4f30c0-bce6-416b-8904-fab4055a7362', 'name': '10 Barrel Brewing Co - Boise', 'brewery_type': 'large', 'address_1': '826 W Bannock St', 'address_2': None, 'address_3': None, 'city': 'Boise', 'state_province': 'Idaho', 'postal_code': '83702-5857', 'country': 'United States', 'longitude': '-116.202929', 'latitude': '43.618516', 'phone': '2083445870', 'website_url': 'http://www.10barrel.com', 'state': 'Id ...

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\marge\anaconda3\lib\site-packages (4.6.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\marge\anaconda3\lib\site-packages (from pymongo[srv]) (2.6.1)

# %%
import requests
import time
from pymongo import MongoClient


client = MongoClient("mongodb+srv://margegbe:k6ewklnVWbhGuNIE@cluster123.jmfakxo.mongodb.net/breweryData?retryWrites=true&w=majority")
db = client.get_database('breweryData')
records = db.Brewery

while True:
    try:
        # Attempt to fetch data from the Open Brewery DB API
        r = requests.get("https://api.openbrewerydb.org/breweries")
        if r.status_code == 200:
            data = r.json()
            # Insert data into MongoDB collection
            if data:
                insert_result = records.insert_many(data)
                print(f"Inserted {len(insert_result.inserted_ids)} records.")
            else:
                print("No data fetched from API.")
        else:
            print(f"Failed to fetch data: Status code {r.status_code}")
            break  
        
        # Sleep for 60 seconds before the next fetch
        time.sleep(60)
        
    except requests.exceptions.RequestException as e:
        print(f"Request exception occurred: {e}")
        break  
        
    except Exception as e:
        print(f"An error occurred: {e}")
        break
# Out:
# Inserted 50 records.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 27
#      24         break
#      26     # Sleep for 60 seconds before the next fetch
# ---> 27     time.sleep(60)
#      29 except requests.exceptions.RequestException as e:
#      30     print(f"Request exception occurred: {e}")
#
# KeyboardInterrupt:

# %%
import requests
import time
from pymongo import MongoClient

client = MongoClient("mongodb+srv://margegbe:k6ewklnVWbhGuNIE@cluster123.jmfakxo.mongodb.net/breweryData?retryWrites=true&w=majority")
db = client.get_database('breweryData')
records = db.Brewery

list(records.find({}))
# Out:
# [{'_id': ObjectId('661787ec291b18a970391f73'),
#   'id': '5128df48-79fc-4f0f-8b52-d06be54d0cec',
#   'name': '(405) Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '1716 Topeka St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Norman',
#   'state_province': 'Oklahoma',
#   'postal_code': '73069-8224',
#   'country': 'United States',
#   'longitude': '-97.46818222',
#   'latitude': '35.25738891',
#   'phone': '4058160490',
#   'website_url': 'http://www.405brewing.com',
#   'state': 'Oklahoma',
#   'street': '1716 Topeka St'},
#  {'_id': ObjectId('661787ec291b18a970391f74'),
#   'id': '9c5a66c8-cc13-416f-a5d9-0a769c87d318',
#   'name': '(512) Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '407 Radam Ln Ste F200',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Austin',
#   'state_province': 'Texas',
#   'postal_code': '78745-1197',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '5129211545',
#   'website_url': 'http://www.512brewing.com',
#   'state': 'Texas',
#   'street': '407 Radam Ln Ste F200'},
#  {'_id': ObjectId('661787ec291b18a970391f75'),
#   'id': '34e8c68b-6146-453f-a4b9-1f6cd99a5ada',
#   'name': '1 of Us Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '8100 Washington Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mount Pleasant',
#   'state_province': 'Wisconsin',
#   'postal_code': '53406-3920',
#   'country': 'United States',
#   'longitude': '-87.88336350209435',
#   'latitude': '42.72010826899558',
#   'phone': '2624847553',
#   'website_url': 'https://www.1ofusbrewing.com',
#   'state': 'Wisconsin',
#   'street': '8100 Washington Ave'},
#  {'_id': ObjectId('661787ec291b18a970391f76'),
#   'id': 'ef970757-fe42-416f-931d-722451f1f59c',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1501 E St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'San Diego',
#   'state_province': 'California',
#   'postal_code': '92101-6618',
#   'country': 'United States',
#   'longitude': '-117.129593',
#   'latitude': '32.714813',
#   'phone': '6195782311',
#   'website_url': 'http://10barrel.com',
#   'state': 'California',
#   'street': '1501 E St'},
#  {'_id': ObjectId('661787ec291b18a970391f77'),
#   'id': '6d14b220-8926-4521-8d19-b98a2d6ec3db',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '62970 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97701-9847',
#   'country': 'United States',
#   'longitude': '-121.281706',
#   'latitude': '44.08683531',
#   'phone': '5415851007',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Oregon',
#   'street': '62970 18th St'},
#  {'_id': ObjectId('661787ec291b18a970391f78'),
#   'id': 'e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1135 NW Galveston Ave Ste B',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97703-2465',
#   'country': 'United States',
#   'longitude': '-121.3288021',
#   'latitude': '44.0575649',
#   'phone': '5415851007',
#   'website_url': None,
#   'state': 'Oregon',
#   'street': '1135 NW Galveston Ave Ste B'},
#  {'_id': ObjectId('661787ec291b18a970391f79'),
#   'id': 'e432899b-7f58-455f-9c7b-9a6e2130a1e0',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1411 NW Flanders St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state_province': 'Oregon',
#   'postal_code': '97209-2620',
#   'country': 'United States',
#   'longitude': '-122.6855056',
#   'latitude': '45.5259786',
#   'phone': '5032241700',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Oregon',
#   'street': '1411 NW Flanders St'},
#  {'_id': ObjectId('661787ec291b18a970391f7a'),
#   'id': '9f1852da-c312-42da-9a31-097bac81c4c0',
#   'name': '10 Barrel Brewing Co - Bend Pub',
#   'brewery_type': 'large',
#   'address_1': '62950 NE 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97701',
#   'country': 'United States',
#   'longitude': '-121.2809536',
#   'latitude': '44.0912109',
#   'phone': '5415851007',
#   'website_url': None,
#   'state': 'Oregon',
#   'street': '62950 NE 18th St'},
#  {'_id': ObjectId('661787ec291b18a970391f7b'),
#   'id': 'ea4f30c0-bce6-416b-8904-fab4055a7362',
#   'name': '10 Barrel Brewing Co - Boise',
#   'brewery_type': 'large',
#   'address_1': '826 W Bannock St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Boise',
#   'state_province': 'Idaho',
#   'postal_code': '83702-5857',
#   'country': 'United States',
#   'longitude': '-116.202929',
#   'latitude': '43.618516',
#   'phone': '2083445870',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Idaho',
#   'street': '826 W Bannock St'},
#  {'_id': ObjectId('661787ec291b18a970391f7c'),
#   'id': '1988eb86-f0a2-4674-ba04-02454efa0d31',
#   'name': '10 Barrel Brewing Co - Denver',
#   'brewery_type': 'large',
#   'address_1': '2620 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state_province': 'Colorado',
#   'postal_code': '80205-2231',
#   'country': 'United States',
#   'longitude': '-104.9853655',
#   'latitude': '39.7592508',
#   'phone': '7205738992',
#   'website_url': None,
#   'state': 'Colorado',
#   'street': '2620 Walnut St'},
#  {'_id': ObjectId('661787ec291b18a970391f7d'),
#   'id': '1ecc330f-6275-42a5-b14e-00adbed62752',
#   'name': '10 Torr Distilling and Brewing',
#   'brewery_type': 'micro',
#   'address_1': '490 Mill St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Reno',
#   'state_province': 'Nevada',
#   'postal_code': '89502',
#   'country': 'United States',
#   'longitude': '-119.7732015',
#   'latitude': '39.5171702',
#   'phone': '7755307014',
#   'website_url': 'http://www.10torr.com',
#   'state': 'Nevada',
#   'street': '490 Mill St'},
#  {'_id': ObjectId('661787ec291b18a970391f7e'),
#   'id': '7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3',
#   'name': '10-56 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '400 Brown Cir',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Knox',
#   'state_province': 'Indiana',
#   'postal_code': '46534',
#   'country': 'United States',
#   'longitude': '-86.627954',
#   'latitude': '41.289715',
#   'phone': '6308165790',
#   'website_url': None,
#   'state': 'Indiana',
#   'street': '400 Brown Cir'},
#  {'_id': ObjectId('661787ec291b18a970391f7f'),
#   'id': '03118499-a3d0-4c22-860d-4529509ae095',
#   'name': '101 Brewery',
#   'brewery_type': 'brewpub',
#   'address_1': '294793 US Highway 101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Quilcene',
#   'state_province': 'Washington',
#   'postal_code': '98376-9000',
#   'country': 'United States',
#   'longitude': '-122.8755823',
#   'latitude': '47.82347577',
#   'phone': '3607656485',
#   'website_url': 'http://www.101brewery.com',
#   'state': 'Washington',
#   'street': '294793 US Highway 101'},
#  {'_id': ObjectId('661787ec291b18a970391f80'),
#   'id': '5ae467af-66dc-4d7f-8839-44228f89b596',
#   'name': '101 North Brewing Company',
#   'brewery_type': 'closed',
#   'address_1': '1304 Scott St Ste D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Petaluma',
#   'state_province': 'California',
#   'postal_code': '94954-7100',
#   'country': 'United States',
#   'longitude': '-122.665055',
#   'latitude': '38.27029381',
#   'phone': '7077534934',
#   'website_url': 'http://www.101northbeer.com',
#   'state': 'California',
#   'street': '1304 Scott St Ste D'},
#  {'_id': ObjectId('661787ec291b18a970391f81'),
#   'id': '4ffda196-dd59-44a5-9eeb-5f7fd4b58f5a',
#   'name': '105 West Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '1043 Park St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Castle Rock',
#   'state_province': 'Colorado',
#   'postal_code': '80109-1585',
#   'country': 'United States',
#   'longitude': '-104.8667206',
#   'latitude': '39.38269495',
#   'phone': '3033257321',
#   'website_url': 'http://www.105westbrewing.com',
#   'state': 'Colorado',
#   'street': '1043 Park St'},
#  {'_id': ObjectId('661787ec291b18a970391f82'),
#   'id': '42aa37d5-8384-4ffe-8c81-7c982eff0384',
#   'name': '10K Brewing',
#   'brewery_type': 'micro',
#   'address_1': '2005 2nd Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Anoka',
#   'state_province': 'Minnesota',
#   'postal_code': '55303-2243',
#   'country': 'United States',
#   'longitude': '-93.38952559',
#   'latitude': '45.19812039',
#   'phone': '7633924753',
#   'website_url': 'http://10KBrew.com',
#   'state': 'Minnesota',
#   'street': '2005 2nd Ave'},
#  {'_id': ObjectId('661787ec291b18a970391f83'),
#   'id': '232e8f62-9afc-45f5-b4bc-582c26b5c43b',
#   'name': '10th District Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '491 Washington St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Abington',
#   'state_province': 'Massachusetts',
#   'postal_code': '02351-2419',
#   'country': 'United States',
#   'longitude': '-70.94594149',
#   'latitude': '42.10591754',
#   'phone': '7813071554',
#   'website_url': 'http://www.10thdistrictbrewing.com',
#   'state': 'Massachusetts',
#   'street': '491 Washington St'},
#  {'_id': ObjectId('661787ec291b18a970391f84'),
#   'id': '08f78223-24f8-4b71-b381-ea19a5bd82df',
#   'name': '11 Below Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '6820 Bourgeois Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Houston',
#   'state_province': 'Texas',
#   'postal_code': '77066-3107',
#   'country': 'United States',
#   'longitude': '-95.5186591',
#   'latitude': '29.9515464',
#   'phone': '2814442337',
#   'website_url': 'http://www.11belowbrewing.com',
#   'state': 'Texas',
#   'street': '6820 Bourgeois Rd'},
#  {'_id': ObjectId('661787ec291b18a970391f85'),
#   'id': '58293321-14ae-49d7-9a7b-08436c9e63a6',
#   'name': '1188 Brewing Co',
#   'brewery_type': 'brewpub',
#   'address_1': '141 E Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'John Day',
#   'state_province': 'Oregon',
#   'postal_code': '97845-1210',
#   'country': 'United States',
#   'longitude': '-118.9218754',
#   'latitude': '44.4146563',
#   'phone': '5415751188',
#   'website_url': 'http://www.1188brewing.com',
#   'state': 'Oregon',
#   'street': '141 E Main St'},
#  {'_id': ObjectId('661787ec291b18a970391f86'),
#   'id': 'e5f3e72a-fee2-4813-82cf-f2e53b439ae6',
#   'name': '12 Acres Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': 'Unnamed Street',
#   'address_2': 'Clonmore',
#   'address_3': None,
#   'city': 'Killeshin',
#   'state_province': 'Laois',
#   'postal_code': 'R93 X3X8',
#   'country': 'Ireland',
#   'longitude': '-6.979343891',
#   'latitude': '52.84930763',
#   'phone': '353599107299',
#   'website_url': 'https://12acresbrewing.ie/',
#   'state': 'Laois',
#   'street': 'Unnamed Street'},
#  {'_id': ObjectId('661787ec291b18a970391f87'),
#   'id': 'd81ff708-b5d2-478f-af6a-6d40f5beb9ac',
#   'name': '12 Gates Brewing Company',
#   'brewery_type': 'brewpub',
#   'address_1': '80 Earhart Dr Ste 20',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Williamsville',
#   'state_province': 'New York',
#   'postal_code': '14221-7804',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '7169066600',
#   'website_url': 'http://www.12gatesbrewing.com',
#   'state': 'New York',
#   'street': '80 Earhart Dr Ste 20'},
#  {'_id': ObjectId('661787ec291b18a970391f88'),
#   'id': 'fb94830f-6196-4f59-9189-c9060b778085',
#   'name': '12 West Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '3000 E Ray Rd Bldg 6',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gilbert',
#   'state_province': 'Arizona',
#   'postal_code': '85296-7832',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6023395014',
#   'website_url': 'http://www.12westbrewing.com',
#   'state': 'Arizona',
#   'street': '3000 E Ray Rd Bldg 6'},
#  {'_id': ObjectId('661787ec291b18a970391f89'),
#   'id': '0faa0fb2-fffa-416d-9eab-46f67477c8ef',
#   'name': '12 West Brewing Company - Production Facility',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mesa',
#   'state_province': 'Arizona',
#   'postal_code': '85207',
#   'country': 'United States',
#   'longitude': '-111.5860662',
#   'latitude': '33.436188',
#   'phone': None,
#   'website_url': None,
#   'state': 'Arizona',
#   'street': None},
#  {'_id': ObjectId('661787ec291b18a970391f8a'),
#   'id': 'e54c2f02-acd6-4172-861d-fcfa54c8701a',
#   'name': '122 West Brewing Co',
#   'brewery_type': 'closed',
#   'address_1': '2416 Meridian St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bellingham',
#   'state_province': 'Washington',
#   'postal_code': '98225-2405',
#   'country': 'United States',
#   'longitude': '-122.485982',
#   'latitude': '48.7621709',
#   'phone': '3603063285',
#   'website_url': 'https://www.122westbrew.com/',
#   'state': 'Washington',
#   'street': '2416 Meridian St'},
#  {'_id': ObjectId('661787ec291b18a970391f8b'),
#   'id': 'd5cb896d-3e99-4e19-9693-5e06ce987e53',
#   'name': '127 Brewing',
#   'brewery_type': 'micro',
#   'address_1': '3090 Shirley Dr',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Jackson',
#   'state_province': 'Michigan',
#   'postal_code': '49201-7010',
#   'country': 'United States',
#   'longitude': '-84.43116792',
#   'latitude': '42.28667212',
#   'phone': '5172581346',
#   'website_url': None,
#   'state': 'Michigan',
#   'street': '3090 Shirley Dr'},
#  {'_id': ObjectId('661787ec291b18a970391f8c'),
#   'id': '06e9fffb-e820-45c9-b107-b52b51013e8f',
#   'name': '12Degree Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '820 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Louisville',
#   'state_province': 'Colorado',
#   'postal_code': '80027-1865',
#   'country': 'United States',
#   'longitude': '-105.1319826',
#   'latitude': '39.9782443',
#   'phone': '3035791004',
#   'website_url': 'http://www.12degree.com',
#   'state': 'Colorado',
#   'street': '820 Main St'},
#  {'_id': ObjectId('661787ec291b18a970391f8d'),
#   'id': '50521ef7-f543-4c5d-98b1-0d0ee1a2be01',
#   'name': '12welve Eyes Brewing',
#   'brewery_type': 'micro',
#   'address_1': '141 E 4th St Ste LL2',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Paul',
#   'state_province': 'Minnesota',
#   'postal_code': '55101-1639',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6514938106',
#   'website_url': 'http://www.12welveEyes.com',
#   'state': 'Minnesota',
#   'street': '141 E 4th St Ste LL2'},
#  {'_id': ObjectId('661787ec291b18a970391f8e'),
#   'id': '950180bd-29c9-46b3-ad0c-e6f09799ec7f',
#   'name': '13 Below Brewery',
#   'brewery_type': 'micro',
#   'address_1': '7391 Forbes Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Cincinnati',
#   'state_province': 'Ohio',
#   'postal_code': '45233-1013',
#   'country': 'United States',
#   'longitude': '-84.70634815',
#   'latitude': '39.12639764',
#   'phone': '5139750613',
#   'website_url': 'http://www.13belowbrewery.com',
#   'state': 'Ohio',
#   'street': '7391 Forbes Rd'},
#  {'_id': ObjectId('661787ec291b18a970391f8f'),
#   'id': '45119c56-345b-4adc-b481-c5cf7bfe98c4',
#   'name': '13 Stripes Brewery',
#   'brewery_type': 'brewpub',
#   'address_1': '250 Mill St, Suite PW3101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Taylors',
#   'state_province': 'South Carolina',
#   'postal_code': '29687',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8643491430',
#   'website_url': 'http://www.13StripesBrewery.com',
#   'state': 'South Carolina',
#   'street': '250 Mill St, Suite PW3101'},
#  {'_id': ObjectId('661787ec291b18a970391f90'),
#   'id': '936c3d7e-5d54-4459-b72c-117cdda059b4',
#   'name': '13 Virtues Brewing Co',
#   'brewery_type': 'brewpub',
#   'address_1': '6410 SE Milwaukie Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state_province': 'Oregon',
#   'postal_code': '97202-5518',
#   'country': 'United States',
#   'longitude': '-122.6487531',
#   'latitude': '45.4762536',
#   'phone': '5032393831',
#   'website_url': 'http://www.13virtuesbrewing.com',
#   'state': 'Oregon',
#   'street': '6410 SE Milwaukie Ave'},
#  {'_id': ObjectId('661787ec291b18a970391f91'),
#   'id': '5c53b314-ebab-4e3e-89be-e4139d9318ae',
#   'name': '1323 R & D',
#   'brewery_type': 'micro',
#   'address_1': '1323 Capital Blvd 1323 R and D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Raleigh',
#   'state_province': 'North Carolina',
#   'postal_code': '27603-1117',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '9199775654',
#   'website_url': 'http://www.1323rnd.com',
#   'state': 'North Carolina',
#   'street': '1323 Capital Blvd 1323 R and D'},
#  {'_id': ObjectId('661787ec291b18a970391f92'),
#   'id': '4788221a-a03b-458c-9084-4cadd69ade6d',
#   'name': '14 Cannons Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '31125 Via Colinas Ste 907',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westlake Village',
#   'state_province': 'California',
#   'postal_code': '91362-3974',
#   'country': 'United States',
#   'longitude': '-118.802397',
#   'latitude': '34.15334',
#   'phone': '8186996165',
#   'website_url': 'http://14cannons.com',
#   'state': 'California',
#   'street': '31125 Via Colinas Ste 907'},
#  {'_id': ObjectId('661787ec291b18a970391f93'),
#   'id': 'b7b68d22-5045-4501-b9bf-ec94946eaffc',
#   'name': '14 Lakes Brewery',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Crosslake',
#   'state_province': 'Minnesota',
#   'postal_code': '56442',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '2186924129',
#   'website_url': None,
#   'state': 'Minnesota',
#   'street': None},
#  {'_id': ObjectId('661787ec291b18a970391f94'),
#   'id': '4b677b60-fef1-42e2-90ef-dadc1bd7fb06',
#   'name': '14er Brewing Company',
#   'brewery_type': 'proprietor',
#   'address_1': '2801 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state_province': 'Colorado',
#   'postal_code': '80205-2235',
#   'country': 'United States',
#   'longitude': '-104.9839636',
#   'latitude': '39.7614112',
#   'phone': '7207731437',
#   'website_url': 'http://www.14erBrewing.com',
#   'state': 'Colorado',
#   'street': '2801 Walnut St'},
#  {'_id': ObjectId('661787ec291b18a970391f95'),
#   'id': '6c53984f-fac1-4ea7-9c44-44e25897c71a',
#   'name': '14th Star Brewing',
#   'brewery_type': 'micro',
#   'address_1': '133 N Main St Ste 7',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Albans',
#   'state_province': 'Vermont',
#   'postal_code': '05478-1735',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8025285988',
#   'website_url': 'http://www.14thstarbrewing.com',
#   'state': 'Vermont',
#   'street': '133 N Main St Ste 7'},
#  {'_id': ObjectId('661787ec291b18a970391f96'),
#   'id': '85192a9c-58a4-48c3-bd9d-496d09d22aa3',
#   'name': '16 Lots Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '753 Reading Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mason',
#   'state_province': 'Ohio',
#   'postal_code': '45040-1303',
#   'country': 'United States',
#   'longitude': '-84.3183801',
#   'latitude': '39.3545967',
#   'phone': '5134863672',
#   'website_url': 'http://www.16lots.com',
#   'state': 'Ohio',
#   'street': '753 Reading Rd'},
#  {'_id': ObjectId('661787ec291b18a970391f97'),
#   'id': '284b44f8-6ccb-4cd6-8d06-f2ad882a47c3',
#   'name': '16 Mile Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '413 S Bedford St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Georgetown',
#   'state_province': 'Delaware',
#   'postal_code': '19947-1849',
#   'country': 'United States',
#   'longitude': '-75.37816436',
#   'latitude': '38.6788938',
#   'phone': '3022538816',
#   'website_url': 'http://www.16milebrewery.com',
#   'state': 'Delaware',
#   'street': '413 S Bedford St'},
#  {'_id': ObjectId('661787ec291b18a970391f98'),
#   'id': 'ee6d39c6-092f-4623-8099-5b8643f70dbe',
#   'name': '16 Stone Brewpub',
#   'brewery_type': 'brewpub',
#   'address_1': '9542 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Holland Patent',
#   'state_province': 'New York',
#   'postal_code': '13354',
#   'country': 'United States',
#   'longitude': '-75.2565195',
#   'latitude': '43.24211175',
#   'phone': '3158658500',
#   'website_url': 'http://www.16stonebrewpub.com',
#   'state': 'New York',
#   'street': '9542 Main St'},
#  {'_id': ObjectId('661787ec291b18a970391f99'),
#   'id': 'd35b40b0-a3ff-4878-a6ee-9caa2149b521',
#   'name': '1623 Brewing CO, llc',
#   'brewery_type': 'contract',
#   'address_1': '1146 colonel Joshua Ct',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westminister',
#   'state_province': 'Maryland',
#   'postal_code': '21157',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': None,
#   'website_url': None,
#   'state': 'Maryland',
#   'street': '1146 colonel Joshua Ct'},
#  {'_id': ObjectId('661787ec291b18a970391f9a'),
#   'id': '84bd3b3c-bd2d-4e07-bc31-b43a8c8ebf4c',
#   'name': '1717 Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '322 E Court Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Des Moines',
#   'state_province': 'Iowa',
#   'postal_code': '50309-2015',
#   'country': 'United States',
#   'longitude': '-93.6120353',
#   'latitude': '41.5872267',
#   'phone': '5152437868',
#   'website_url': 'http://1717brewing.com',
#   'state': 'Iowa',
#   'street': '322 E Court Ave'},
#  {'_id': ObjectId('661787ec291b18a970391f9b'),
#   'id': 'f41a0c47-ba9b-4547-bfed-fcbefe0fc74b',
#   'name': '1718 Ocracoke Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '1129 Irvin Garrish Hwy',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Ocracoke',
#   'state_province': 'North Carolina',
#   'postal_code': '27960',
#   'country': 'United States',
#   'longitude': '-75.97176063',
#   'latitude': '35.10715368',
#   'phone': '2529282337',
#   'website_url': 'http://www.ocracokebrewing.com',
#   'state': 'North Carolina',
#   'street': '1129 Irvin Garrish Hwy'},
#  {'_id': ObjectId('661787ec291b18a970391f9c'),
#   'id': '84d621c4-81a5-44e6-aca7-1566c2e67cc0',
#   'name': '1781 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '11109 Plank Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Spotsylvania',
#   'state_province': 'Virginia',
#   'postal_code': '22553-4258',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '5408412598',
#   'website_url': None,
#   'state': 'Virginia',
#   'street': '11109 Plank Rd'},
#  {'_id': ObjectId('661787ec291b18a970391f9d'),
#   'id': '896f26a1-d80e-4790-9287-026a86c1799d',
#   'name': '180 and Tapped',
#   'brewery_type': 'micro',
#   'address_1': '2010 A State Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Coraopolis',
#   'state_province': 'Pennsylvania',
#   'postal_code': '15108',
#   'country': 'United States',
#   'longitude': '-80.15020356',
#   'latitude': '40.50984957',
#   'phone': '4127375273',
#   'website_url': 'http://www.180andtapped.com',
#   'state': 'Pennsylvania',
#   'street': '2010 A State Ave'},
#  {'_id': ObjectId('661787ec291b18a970391f9e'),
#   'id': '46839a79-b7bf-4733-b91b-ce116d062a57',
#   'name': '1817 Brewery',
#   'brewery_type': 'micro',
#   'address_1': '100 B South Olive St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'okolona',
#   'state_province': 'Mississippi',
#   'postal_code': '38860',
#   'country': 'United States',
#   'longitude': '-88.750264',
#   'latitude': '34.001703',
#   'phone': '6623055907',
#   'website_url': None,
#   'state': 'Mississippi',
#   'street': '100 B South Olive St'},
#  {'_id': ObjectId('661787ec291b18a970391f9f'),
#   'id': '1a1b2165-73ed-40aa-b89b-56794d140f22',
#   'name': '1840 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '342 E Ward St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Milwaukee',
#   'state_province': 'Wisconsin',
#   'postal_code': '53207-1348',
#   'country': 'United States',
#   'longitude': '-87.90606942',
#   'latitude': '43.00436242',
#   'phone': '4142364056',
#   'website_url': 'http://www.1840brewing.com',
#   'state': 'Wisconsin',
#   'street': '342 E Ward St'},
#  {'_id': ObjectId('661787ec291b18a970391fa0'),
#   'id': 'fe6b9893-b93e-43d5-a9f6-3e0c89a3f13c',
#   'name': '1850 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mariposa',
#   'state_province': 'California',
#   'postal_code': '95338',
#   'country': 'United States',
#   'longitude': '-119.9036592',
#   'latitude': '37.570148',
#   'phone': None,
#   'website_url': 'http://www.1850restaurant.com',
#   'state': 'California',
#   'street': None},
#  {'_id': ObjectId('661787ec291b18a970391fa1'),
#   'id': 'b51f3cdf-60ff-4ae1-94a7-76906c7d62eb',
#   'name': '18th Street Brewery',
#   'brewery_type': 'micro',
#   'address_1': '5725 Miller Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gary',
#   'state_province': 'Indiana',
#   'postal_code': '46403-2871',
#   'country': 'United States',
#   'longitude': '-87.26887786',
#   'latitude': '41.59928343',
#   'phone': None,
#   'website_url': 'http://www.18thstreetbrewery.com',
#   'state': 'Indiana',
#   'street': '5725 Miller Ave'},
#  {'_id': ObjectId('661787ec291b18a970391fa2'),
#   'id': 'add7f978-942e-4d56-b209-c80837a51d69',
#   'name': '18th Street Brewery',
#   'brewery_type': 'micro',
#   'address_1': '5417 Oakley Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Hammond',
#   'state_province': 'Indiana',
#   'postal_code': '46320-1817',
#   'country': 'United States',
#   'longitude': '-87.517422',
#   'latitude': '41.61556796',
#   'phone': None,
#   'website_url': None,
#   'state': 'Indiana',
#   'street': '5417 Oakley Ave'},
#  {'_id': ObjectId('661787ec291b18a970391fa3'),
#   'id': 'dbde8235-2b55-4d8b-8b1c-438155abe104',
#   'name': '1905 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '1301 S Chestnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Assumption',
#   'state_province': 'Illinois',
#   'postal_code': '62510-8504',
#   'country': 'United States',
#   'longitude': '-89.0503635',
#   'latitude': '39.5172564',
#   'phone': '2172549374',
#   'website_url': 'http://1905BrewingCompany.com',
#   'state': 'Illinois',
#   'street': '1301 S Chestnut St'},
#  {'_id': ObjectId('661787ec291b18a970391fa4'),
#   'id': '4f4b5b34-d572-4dff-a18f-47e507c073e6',
#   'name': '1912 Brewing',
#   'brewery_type': 'micro',
#   'address_1': '2045 N Forbes Blvd Ste 105',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Tucson',
#   'state_province': 'Arizona',
#   'postal_code': '85745-1444',
#   'country': 'United States',
#   'longitude': '-110.9927505',
#   'latitude': '32.24673727',
#   'phone': '5202564851',
#   'website_url': 'http://www.1912brewing.com',
#   'state': 'Arizona',
#   'street': '2045 N Forbes Blvd Ste 105'},
#  {'_id': ObjectId('66178829291b18a970391fa5'),
#   'id': '5128df48-79fc-4f0f-8b52-d06be54d0cec',
#   'name': '(405) Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '1716 Topeka St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Norman',
#   'state_province': 'Oklahoma',
#   'postal_code': '73069-8224',
#   'country': 'United States',
#   'longitude': '-97.46818222',
#   'latitude': '35.25738891',
#   'phone': '4058160490',
#   'website_url': 'http://www.405brewing.com',
#   'state': 'Oklahoma',
#   'street': '1716 Topeka St'},
#  {'_id': ObjectId('66178829291b18a970391fa6'),
#   'id': '9c5a66c8-cc13-416f-a5d9-0a769c87d318',
#   'name': '(512) Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '407 Radam Ln Ste F200',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Austin',
#   'state_province': 'Texas',
#   'postal_code': '78745-1197',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '5129211545',
#   'website_url': 'http://www.512brewing.com',
#   'state': 'Texas',
#   'street': '407 Radam Ln Ste F200'},
#  {'_id': ObjectId('66178829291b18a970391fa7'),
#   'id': '34e8c68b-6146-453f-a4b9-1f6cd99a5ada',
#   'name': '1 of Us Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '8100 Washington Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mount Pleasant',
#   'state_province': 'Wisconsin',
#   'postal_code': '53406-3920',
#   'country': 'United States',
#   'longitude': '-87.88336350209435',
#   'latitude': '42.72010826899558',
#   'phone': '2624847553',
#   'website_url': 'https://www.1ofusbrewing.com',
#   'state': 'Wisconsin',
#   'street': '8100 Washington Ave'},
#  {'_id': ObjectId('66178829291b18a970391fa8'),
#   'id': 'ef970757-fe42-416f-931d-722451f1f59c',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1501 E St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'San Diego',
#   'state_province': 'California',
#   'postal_code': '92101-6618',
#   'country': 'United States',
#   'longitude': '-117.129593',
#   'latitude': '32.714813',
#   'phone': '6195782311',
#   'website_url': 'http://10barrel.com',
#   'state': 'California',
#   'street': '1501 E St'},
#  {'_id': ObjectId('66178829291b18a970391fa9'),
#   'id': '6d14b220-8926-4521-8d19-b98a2d6ec3db',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '62970 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97701-9847',
#   'country': 'United States',
#   'longitude': '-121.281706',
#   'latitude': '44.08683531',
#   'phone': '5415851007',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Oregon',
#   'street': '62970 18th St'},
#  {'_id': ObjectId('66178829291b18a970391faa'),
#   'id': 'e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1135 NW Galveston Ave Ste B',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97703-2465',
#   'country': 'United States',
#   'longitude': '-121.3288021',
#   'latitude': '44.0575649',
#   'phone': '5415851007',
#   'website_url': None,
#   'state': 'Oregon',
#   'street': '1135 NW Galveston Ave Ste B'},
#  {'_id': ObjectId('66178829291b18a970391fab'),
#   'id': 'e432899b-7f58-455f-9c7b-9a6e2130a1e0',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'address_1': '1411 NW Flanders St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state_province': 'Oregon',
#   'postal_code': '97209-2620',
#   'country': 'United States',
#   'longitude': '-122.6855056',
#   'latitude': '45.5259786',
#   'phone': '5032241700',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Oregon',
#   'street': '1411 NW Flanders St'},
#  {'_id': ObjectId('66178829291b18a970391fac'),
#   'id': '9f1852da-c312-42da-9a31-097bac81c4c0',
#   'name': '10 Barrel Brewing Co - Bend Pub',
#   'brewery_type': 'large',
#   'address_1': '62950 NE 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state_province': 'Oregon',
#   'postal_code': '97701',
#   'country': 'United States',
#   'longitude': '-121.2809536',
#   'latitude': '44.0912109',
#   'phone': '5415851007',
#   'website_url': None,
#   'state': 'Oregon',
#   'street': '62950 NE 18th St'},
#  {'_id': ObjectId('66178829291b18a970391fad'),
#   'id': 'ea4f30c0-bce6-416b-8904-fab4055a7362',
#   'name': '10 Barrel Brewing Co - Boise',
#   'brewery_type': 'large',
#   'address_1': '826 W Bannock St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Boise',
#   'state_province': 'Idaho',
#   'postal_code': '83702-5857',
#   'country': 'United States',
#   'longitude': '-116.202929',
#   'latitude': '43.618516',
#   'phone': '2083445870',
#   'website_url': 'http://www.10barrel.com',
#   'state': 'Idaho',
#   'street': '826 W Bannock St'},
#  {'_id': ObjectId('66178829291b18a970391fae'),
#   'id': '1988eb86-f0a2-4674-ba04-02454efa0d31',
#   'name': '10 Barrel Brewing Co - Denver',
#   'brewery_type': 'large',
#   'address_1': '2620 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state_province': 'Colorado',
#   'postal_code': '80205-2231',
#   'country': 'United States',
#   'longitude': '-104.9853655',
#   'latitude': '39.7592508',
#   'phone': '7205738992',
#   'website_url': None,
#   'state': 'Colorado',
#   'street': '2620 Walnut St'},
#  {'_id': ObjectId('66178829291b18a970391faf'),
#   'id': '1ecc330f-6275-42a5-b14e-00adbed62752',
#   'name': '10 Torr Distilling and Brewing',
#   'brewery_type': 'micro',
#   'address_1': '490 Mill St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Reno',
#   'state_province': 'Nevada',
#   'postal_code': '89502',
#   'country': 'United States',
#   'longitude': '-119.7732015',
#   'latitude': '39.5171702',
#   'phone': '7755307014',
#   'website_url': 'http://www.10torr.com',
#   'state': 'Nevada',
#   'street': '490 Mill St'},
#  {'_id': ObjectId('66178829291b18a970391fb0'),
#   'id': '7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3',
#   'name': '10-56 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '400 Brown Cir',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Knox',
#   'state_province': 'Indiana',
#   'postal_code': '46534',
#   'country': 'United States',
#   'longitude': '-86.627954',
#   'latitude': '41.289715',
#   'phone': '6308165790',
#   'website_url': None,
#   'state': 'Indiana',
#   'street': '400 Brown Cir'},
#  {'_id': ObjectId('66178829291b18a970391fb1'),
#   'id': '03118499-a3d0-4c22-860d-4529509ae095',
#   'name': '101 Brewery',
#   'brewery_type': 'brewpub',
#   'address_1': '294793 US Highway 101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Quilcene',
#   'state_province': 'Washington',
#   'postal_code': '98376-9000',
#   'country': 'United States',
#   'longitude': '-122.8755823',
#   'latitude': '47.82347577',
#   'phone': '3607656485',
#   'website_url': 'http://www.101brewery.com',
#   'state': 'Washington',
#   'street': '294793 US Highway 101'},
#  {'_id': ObjectId('66178829291b18a970391fb2'),
#   'id': '5ae467af-66dc-4d7f-8839-44228f89b596',
#   'name': '101 North Brewing Company',
#   'brewery_type': 'closed',
#   'address_1': '1304 Scott St Ste D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Petaluma',
#   'state_province': 'California',
#   'postal_code': '94954-7100',
#   'country': 'United States',
#   'longitude': '-122.665055',
#   'latitude': '38.27029381',
#   'phone': '7077534934',
#   'website_url': 'http://www.101northbeer.com',
#   'state': 'California',
#   'street': '1304 Scott St Ste D'},
#  {'_id': ObjectId('66178829291b18a970391fb3'),
#   'id': '4ffda196-dd59-44a5-9eeb-5f7fd4b58f5a',
#   'name': '105 West Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '1043 Park St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Castle Rock',
#   'state_province': 'Colorado',
#   'postal_code': '80109-1585',
#   'country': 'United States',
#   'longitude': '-104.8667206',
#   'latitude': '39.38269495',
#   'phone': '3033257321',
#   'website_url': 'http://www.105westbrewing.com',
#   'state': 'Colorado',
#   'street': '1043 Park St'},
#  {'_id': ObjectId('66178829291b18a970391fb4'),
#   'id': '42aa37d5-8384-4ffe-8c81-7c982eff0384',
#   'name': '10K Brewing',
#   'brewery_type': 'micro',
#   'address_1': '2005 2nd Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Anoka',
#   'state_province': 'Minnesota',
#   'postal_code': '55303-2243',
#   'country': 'United States',
#   'longitude': '-93.38952559',
#   'latitude': '45.19812039',
#   'phone': '7633924753',
#   'website_url': 'http://10KBrew.com',
#   'state': 'Minnesota',
#   'street': '2005 2nd Ave'},
#  {'_id': ObjectId('66178829291b18a970391fb5'),
#   'id': '232e8f62-9afc-45f5-b4bc-582c26b5c43b',
#   'name': '10th District Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '491 Washington St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Abington',
#   'state_province': 'Massachusetts',
#   'postal_code': '02351-2419',
#   'country': 'United States',
#   'longitude': '-70.94594149',
#   'latitude': '42.10591754',
#   'phone': '7813071554',
#   'website_url': 'http://www.10thdistrictbrewing.com',
#   'state': 'Massachusetts',
#   'street': '491 Washington St'},
#  {'_id': ObjectId('66178829291b18a970391fb6'),
#   'id': '08f78223-24f8-4b71-b381-ea19a5bd82df',
#   'name': '11 Below Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '6820 Bourgeois Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Houston',
#   'state_province': 'Texas',
#   'postal_code': '77066-3107',
#   'country': 'United States',
#   'longitude': '-95.5186591',
#   'latitude': '29.9515464',
#   'phone': '2814442337',
#   'website_url': 'http://www.11belowbrewing.com',
#   'state': 'Texas',
#   'street': '6820 Bourgeois Rd'},
#  {'_id': ObjectId('66178829291b18a970391fb7'),
#   'id': '58293321-14ae-49d7-9a7b-08436c9e63a6',
#   'name': '1188 Brewing Co',
#   'brewery_type': 'brewpub',
#   'address_1': '141 E Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'John Day',
#   'state_province': 'Oregon',
#   'postal_code': '97845-1210',
#   'country': 'United States',
#   'longitude': '-118.9218754',
#   'latitude': '44.4146563',
#   'phone': '5415751188',
#   'website_url': 'http://www.1188brewing.com',
#   'state': 'Oregon',
#   'street': '141 E Main St'},
#  {'_id': ObjectId('66178829291b18a970391fb8'),
#   'id': 'e5f3e72a-fee2-4813-82cf-f2e53b439ae6',
#   'name': '12 Acres Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': 'Unnamed Street',
#   'address_2': 'Clonmore',
#   'address_3': None,
#   'city': 'Killeshin',
#   'state_province': 'Laois',
#   'postal_code': 'R93 X3X8',
#   'country': 'Ireland',
#   'longitude': '-6.979343891',
#   'latitude': '52.84930763',
#   'phone': '353599107299',
#   'website_url': 'https://12acresbrewing.ie/',
#   'state': 'Laois',
#   'street': 'Unnamed Street'},
#  {'_id': ObjectId('66178829291b18a970391fb9'),
#   'id': 'd81ff708-b5d2-478f-af6a-6d40f5beb9ac',
#   'name': '12 Gates Brewing Company',
#   'brewery_type': 'brewpub',
#   'address_1': '80 Earhart Dr Ste 20',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Williamsville',
#   'state_province': 'New York',
#   'postal_code': '14221-7804',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '7169066600',
#   'website_url': 'http://www.12gatesbrewing.com',
#   'state': 'New York',
#   'street': '80 Earhart Dr Ste 20'},
#  {'_id': ObjectId('66178829291b18a970391fba'),
#   'id': 'fb94830f-6196-4f59-9189-c9060b778085',
#   'name': '12 West Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '3000 E Ray Rd Bldg 6',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gilbert',
#   'state_province': 'Arizona',
#   'postal_code': '85296-7832',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6023395014',
#   'website_url': 'http://www.12westbrewing.com',
#   'state': 'Arizona',
#   'street': '3000 E Ray Rd Bldg 6'},
#  {'_id': ObjectId('66178829291b18a970391fbb'),
#   'id': '0faa0fb2-fffa-416d-9eab-46f67477c8ef',
#   'name': '12 West Brewing Company - Production Facility',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mesa',
#   'state_province': 'Arizona',
#   'postal_code': '85207',
#   'country': 'United States',
#   'longitude': '-111.5860662',
#   'latitude': '33.436188',
#   'phone': None,
#   'website_url': None,
#   'state': 'Arizona',
#   'street': None},
#  {'_id': ObjectId('66178829291b18a970391fbc'),
#   'id': 'e54c2f02-acd6-4172-861d-fcfa54c8701a',
#   'name': '122 West Brewing Co',
#   'brewery_type': 'closed',
#   'address_1': '2416 Meridian St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bellingham',
#   'state_province': 'Washington',
#   'postal_code': '98225-2405',
#   'country': 'United States',
#   'longitude': '-122.485982',
#   'latitude': '48.7621709',
#   'phone': '3603063285',
#   'website_url': 'https://www.122westbrew.com/',
#   'state': 'Washington',
#   'street': '2416 Meridian St'},
#  {'_id': ObjectId('66178829291b18a970391fbd'),
#   'id': 'd5cb896d-3e99-4e19-9693-5e06ce987e53',
#   'name': '127 Brewing',
#   'brewery_type': 'micro',
#   'address_1': '3090 Shirley Dr',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Jackson',
#   'state_province': 'Michigan',
#   'postal_code': '49201-7010',
#   'country': 'United States',
#   'longitude': '-84.43116792',
#   'latitude': '42.28667212',
#   'phone': '5172581346',
#   'website_url': None,
#   'state': 'Michigan',
#   'street': '3090 Shirley Dr'},
#  {'_id': ObjectId('66178829291b18a970391fbe'),
#   'id': '06e9fffb-e820-45c9-b107-b52b51013e8f',
#   'name': '12Degree Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '820 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Louisville',
#   'state_province': 'Colorado',
#   'postal_code': '80027-1865',
#   'country': 'United States',
#   'longitude': '-105.1319826',
#   'latitude': '39.9782443',
#   'phone': '3035791004',
#   'website_url': 'http://www.12degree.com',
#   'state': 'Colorado',
#   'street': '820 Main St'},
#  {'_id': ObjectId('66178829291b18a970391fbf'),
#   'id': '50521ef7-f543-4c5d-98b1-0d0ee1a2be01',
#   'name': '12welve Eyes Brewing',
#   'brewery_type': 'micro',
#   'address_1': '141 E 4th St Ste LL2',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Paul',
#   'state_province': 'Minnesota',
#   'postal_code': '55101-1639',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6514938106',
#   'website_url': 'http://www.12welveEyes.com',
#   'state': 'Minnesota',
#   'street': '141 E 4th St Ste LL2'},
#  {'_id': ObjectId('66178829291b18a970391fc0'),
#   'id': '950180bd-29c9-46b3-ad0c-e6f09799ec7f',
#   'name': '13 Below Brewery',
#   'brewery_type': 'micro',
#   'address_1': '7391 Forbes Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Cincinnati',
#   'state_province': 'Ohio',
#   'postal_code': '45233-1013',
#   'country': 'United States',
#   'longitude': '-84.70634815',
#   'latitude': '39.12639764',
#   'phone': '5139750613',
#   'website_url': 'http://www.13belowbrewery.com',
#   'state': 'Ohio',
#   'street': '7391 Forbes Rd'},
#  {'_id': ObjectId('66178829291b18a970391fc1'),
#   'id': '45119c56-345b-4adc-b481-c5cf7bfe98c4',
#   'name': '13 Stripes Brewery',
#   'brewery_type': 'brewpub',
#   'address_1': '250 Mill St, Suite PW3101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Taylors',
#   'state_province': 'South Carolina',
#   'postal_code': '29687',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8643491430',
#   'website_url': 'http://www.13StripesBrewery.com',
#   'state': 'South Carolina',
#   'street': '250 Mill St, Suite PW3101'},
#  {'_id': ObjectId('66178829291b18a970391fc2'),
#   'id': '936c3d7e-5d54-4459-b72c-117cdda059b4',
#   'name': '13 Virtues Brewing Co',
#   'brewery_type': 'brewpub',
#   'address_1': '6410 SE Milwaukie Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state_province': 'Oregon',
#   'postal_code': '97202-5518',
#   'country': 'United States',
#   'longitude': '-122.6487531',
#   'latitude': '45.4762536',
#   'phone': '5032393831',
#   'website_url': 'http://www.13virtuesbrewing.com',
#   'state': 'Oregon',
#   'street': '6410 SE Milwaukie Ave'},
#  {'_id': ObjectId('66178829291b18a970391fc3'),
#   'id': '5c53b314-ebab-4e3e-89be-e4139d9318ae',
#   'name': '1323 R & D',
#   'brewery_type': 'micro',
#   'address_1': '1323 Capital Blvd 1323 R and D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Raleigh',
#   'state_province': 'North Carolina',
#   'postal_code': '27603-1117',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '9199775654',
#   'website_url': 'http://www.1323rnd.com',
#   'state': 'North Carolina',
#   'street': '1323 Capital Blvd 1323 R and D'},
#  {'_id': ObjectId('66178829291b18a970391fc4'),
#   'id': '4788221a-a03b-458c-9084-4cadd69ade6d',
#   'name': '14 Cannons Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '31125 Via Colinas Ste 907',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westlake Village',
#   'state_province': 'California',
#   'postal_code': '91362-3974',
#   'country': 'United States',
#   'longitude': '-118.802397',
#   'latitude': '34.15334',
#   'phone': '8186996165',
#   'website_url': 'http://14cannons.com',
#   'state': 'California',
#   'street': '31125 Via Colinas Ste 907'},
#  {'_id': ObjectId('66178829291b18a970391fc5'),
#   'id': 'b7b68d22-5045-4501-b9bf-ec94946eaffc',
#   'name': '14 Lakes Brewery',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Crosslake',
#   'state_province': 'Minnesota',
#   'postal_code': '56442',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '2186924129',
#   'website_url': None,
#   'state': 'Minnesota',
#   'street': None},
#  {'_id': ObjectId('66178829291b18a970391fc6'),
#   'id': '4b677b60-fef1-42e2-90ef-dadc1bd7fb06',
#   'name': '14er Brewing Company',
#   'brewery_type': 'proprietor',
#   'address_1': '2801 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state_province': 'Colorado',
#   'postal_code': '80205-2235',
#   'country': 'United States',
#   'longitude': '-104.9839636',
#   'latitude': '39.7614112',
#   'phone': '7207731437',
#   'website_url': 'http://www.14erBrewing.com',
#   'state': 'Colorado',
#   'street': '2801 Walnut St'},
#  {'_id': ObjectId('66178829291b18a970391fc7'),
#   'id': '6c53984f-fac1-4ea7-9c44-44e25897c71a',
#   'name': '14th Star Brewing',
#   'brewery_type': 'micro',
#   'address_1': '133 N Main St Ste 7',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Albans',
#   'state_province': 'Vermont',
#   'postal_code': '05478-1735',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8025285988',
#   'website_url': 'http://www.14thstarbrewing.com',
#   'state': 'Vermont',
#   'street': '133 N Main St Ste 7'},
#  {'_id': ObjectId('66178829291b18a970391fc8'),
#   'id': '85192a9c-58a4-48c3-bd9d-496d09d22aa3',
#   'name': '16 Lots Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '753 Reading Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mason',
#   'state_province': 'Ohio',
#   'postal_code': '45040-1303',
#   'country': 'United States',
#   'longitude': '-84.3183801',
#   'latitude': '39.3545967',
#   'phone': '5134863672',
#   'website_url': 'http://www.16lots.com',
#   'state': 'Ohio',
#   'street': '753 Reading Rd'},
#  {'_id': ObjectId('66178829291b18a970391fc9'),
#   'id': '284b44f8-6ccb-4cd6-8d06-f2ad882a47c3',
#   'name': '16 Mile Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '413 S Bedford St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Georgetown',
#   'state_province': 'Delaware',
#   'postal_code': '19947-1849',
#   'country': 'United States',
#   'longitude': '-75.37816436',
#   'latitude': '38.6788938',
#   'phone': '3022538816',
#   'website_url': 'http://www.16milebrewery.com',
#   'state': 'Delaware',
#   'street': '413 S Bedford St'},
#  {'_id': ObjectId('66178829291b18a970391fca'),
#   'id': 'ee6d39c6-092f-4623-8099-5b8643f70dbe',
#   'name': '16 Stone Brewpub',
#   'brewery_type': 'brewpub',
#   'address_1': '9542 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Holland Patent',
#   'state_province': 'New York',
#   'postal_code': '13354',
#   'country': 'United States',
#   'longitude': '-75.2565195',
#   'latitude': '43.24211175',
#   'phone': '3158658500',
#   'website_url': 'http://www.16stonebrewpub.com',
#   'state': 'New York',
#   'street': '9542 Main St'},
#  {'_id': ObjectId('66178829291b18a970391fcb'),
#   'id': 'd35b40b0-a3ff-4878-a6ee-9caa2149b521',
#   'name': '1623 Brewing CO, llc',
#   'brewery_type': 'contract',
#   'address_1': '1146 colonel Joshua Ct',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westminister',
#   'state_province': 'Maryland',
#   'postal_code': '21157',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': None,
#   'website_url': None,
#   'state': 'Maryland',
#   'street': '1146 colonel Joshua Ct'},
#  {'_id': ObjectId('66178829291b18a970391fcc'),
#   'id': '84bd3b3c-bd2d-4e07-bc31-b43a8c8ebf4c',
#   'name': '1717 Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '322 E Court Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Des Moines',
#   'state_province': 'Iowa',
#   'postal_code': '50309-2015',
#   'country': 'United States',
#   'longitude': '-93.6120353',
#   'latitude': '41.5872267',
#   'phone': '5152437868',
#   'website_url': 'http://1717brewing.com',
#   'state': 'Iowa',
#   'street': '322 E Court Ave'},
#  {'_id': ObjectId('66178829291b18a970391fcd'),
#   'id': 'f41a0c47-ba9b-4547-bfed-fcbefe0fc74b',
#   'name': '1718 Ocracoke Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '1129 Irvin Garrish Hwy',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Ocracoke',
#   'state_province': 'North Carolina',
#   'postal_code': '27960',
#   'country': 'United States',
#   'longitude': '-75.97176063',
#   'latitude': '35.10715368',
#   'phone': '2529282337',
#   'website_url': 'http://www.ocracokebrewing.com',
#   'state': 'North Carolina',
#   'street': '1129 Irvin Garrish Hwy'},
#  {'_id': ObjectId('66178829291b18a970391fce'),
#   'id': '84d621c4-81a5-44e6-aca7-1566c2e67cc0',
# ...
#   'state_province': 'Laois',
#   'postal_code': 'R93 X3X8',
#   'country': 'Ireland',
#   'longitude': '-6.979343891',
#   'latitude': '52.84930763',
#   'phone': '353599107299',
#   'website_url': 'https://12acresbrewing.ie/',
#   'state': 'Laois',
#   'street': 'Unnamed Street'},
#  {'_id': ObjectId('66178c71291b18a97039233d'),
#   'id': 'd81ff708-b5d2-478f-af6a-6d40f5beb9ac',
#   'name': '12 Gates Brewing Company',
#   'brewery_type': 'brewpub',
#   'address_1': '80 Earhart Dr Ste 20',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Williamsville',
#   'state_province': 'New York',
#   'postal_code': '14221-7804',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '7169066600',
#   'website_url': 'http://www.12gatesbrewing.com',
#   'state': 'New York',
#   'street': '80 Earhart Dr Ste 20'},
#  {'_id': ObjectId('66178c71291b18a97039233e'),
#   'id': 'fb94830f-6196-4f59-9189-c9060b778085',
#   'name': '12 West Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '3000 E Ray Rd Bldg 6',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gilbert',
#   'state_province': 'Arizona',
#   'postal_code': '85296-7832',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6023395014',
#   'website_url': 'http://www.12westbrewing.com',
#   'state': 'Arizona',
#   'street': '3000 E Ray Rd Bldg 6'},
#  {'_id': ObjectId('66178c71291b18a97039233f'),
#   'id': '0faa0fb2-fffa-416d-9eab-46f67477c8ef',
#   'name': '12 West Brewing Company - Production Facility',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mesa',
#   'state_province': 'Arizona',
#   'postal_code': '85207',
#   'country': 'United States',
#   'longitude': '-111.5860662',
#   'latitude': '33.436188',
#   'phone': None,
#   'website_url': None,
#   'state': 'Arizona',
#   'street': None},
#  {'_id': ObjectId('66178c71291b18a970392340'),
#   'id': 'e54c2f02-acd6-4172-861d-fcfa54c8701a',
#   'name': '122 West Brewing Co',
#   'brewery_type': 'closed',
#   'address_1': '2416 Meridian St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bellingham',
#   'state_province': 'Washington',
#   'postal_code': '98225-2405',
#   'country': 'United States',
#   'longitude': '-122.485982',
#   'latitude': '48.7621709',
#   'phone': '3603063285',
#   'website_url': 'https://www.122westbrew.com/',
#   'state': 'Washington',
#   'street': '2416 Meridian St'},
#  {'_id': ObjectId('66178c71291b18a970392341'),
#   'id': 'd5cb896d-3e99-4e19-9693-5e06ce987e53',
#   'name': '127 Brewing',
#   'brewery_type': 'micro',
#   'address_1': '3090 Shirley Dr',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Jackson',
#   'state_province': 'Michigan',
#   'postal_code': '49201-7010',
#   'country': 'United States',
#   'longitude': '-84.43116792',
#   'latitude': '42.28667212',
#   'phone': '5172581346',
#   'website_url': None,
#   'state': 'Michigan',
#   'street': '3090 Shirley Dr'},
#  {'_id': ObjectId('66178c71291b18a970392342'),
#   'id': '06e9fffb-e820-45c9-b107-b52b51013e8f',
#   'name': '12Degree Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '820 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Louisville',
#   'state_province': 'Colorado',
#   'postal_code': '80027-1865',
#   'country': 'United States',
#   'longitude': '-105.1319826',
#   'latitude': '39.9782443',
#   'phone': '3035791004',
#   'website_url': 'http://www.12degree.com',
#   'state': 'Colorado',
#   'street': '820 Main St'},
#  {'_id': ObjectId('66178c71291b18a970392343'),
#   'id': '50521ef7-f543-4c5d-98b1-0d0ee1a2be01',
#   'name': '12welve Eyes Brewing',
#   'brewery_type': 'micro',
#   'address_1': '141 E 4th St Ste LL2',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Paul',
#   'state_province': 'Minnesota',
#   'postal_code': '55101-1639',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6514938106',
#   'website_url': 'http://www.12welveEyes.com',
#   'state': 'Minnesota',
#   'street': '141 E 4th St Ste LL2'},
#  {'_id': ObjectId('66178c71291b18a970392344'),
#   'id': '950180bd-29c9-46b3-ad0c-e6f09799ec7f',
#   'name': '13 Below Brewery',
#   'brewery_type': 'micro',
#   'address_1': '7391 Forbes Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Cincinnati',
#   'state_province': 'Ohio',
#   'postal_code': '45233-1013',
#   'country': 'United States',
#   'longitude': '-84.70634815',
#   'latitude': '39.12639764',
#   'phone': '5139750613',
#   'website_url': 'http://www.13belowbrewery.com',
#   'state': 'Ohio',
#   'street': '7391 Forbes Rd'},
#  {'_id': ObjectId('66178c71291b18a970392345'),
#   'id': '45119c56-345b-4adc-b481-c5cf7bfe98c4',
#   'name': '13 Stripes Brewery',
#   'brewery_type': 'brewpub',
#   'address_1': '250 Mill St, Suite PW3101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Taylors',
#   'state_province': 'South Carolina',
#   'postal_code': '29687',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8643491430',
#   'website_url': 'http://www.13StripesBrewery.com',
#   'state': 'South Carolina',
#   'street': '250 Mill St, Suite PW3101'},
#  {'_id': ObjectId('66178c71291b18a970392346'),
#   'id': '936c3d7e-5d54-4459-b72c-117cdda059b4',
#   'name': '13 Virtues Brewing Co',
#   'brewery_type': 'brewpub',
#   'address_1': '6410 SE Milwaukie Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state_province': 'Oregon',
#   'postal_code': '97202-5518',
#   'country': 'United States',
#   'longitude': '-122.6487531',
#   'latitude': '45.4762536',
#   'phone': '5032393831',
#   'website_url': 'http://www.13virtuesbrewing.com',
#   'state': 'Oregon',
#   'street': '6410 SE Milwaukie Ave'},
#  {'_id': ObjectId('66178c71291b18a970392347'),
#   'id': '5c53b314-ebab-4e3e-89be-e4139d9318ae',
#   'name': '1323 R & D',
#   'brewery_type': 'micro',
#   'address_1': '1323 Capital Blvd 1323 R and D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Raleigh',
#   'state_province': 'North Carolina',
#   'postal_code': '27603-1117',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '9199775654',
#   'website_url': 'http://www.1323rnd.com',
#   'state': 'North Carolina',
#   'street': '1323 Capital Blvd 1323 R and D'},
#  {'_id': ObjectId('66178c71291b18a970392348'),
#   'id': '4788221a-a03b-458c-9084-4cadd69ade6d',
#   'name': '14 Cannons Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '31125 Via Colinas Ste 907',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westlake Village',
#   'state_province': 'California',
#   'postal_code': '91362-3974',
#   'country': 'United States',
#   'longitude': '-118.802397',
#   'latitude': '34.15334',
#   'phone': '8186996165',
#   'website_url': 'http://14cannons.com',
#   'state': 'California',
#   'street': '31125 Via Colinas Ste 907'},
#  {'_id': ObjectId('66178c71291b18a970392349'),
#   'id': 'b7b68d22-5045-4501-b9bf-ec94946eaffc',
#   'name': '14 Lakes Brewery',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Crosslake',
#   'state_province': 'Minnesota',
#   'postal_code': '56442',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '2186924129',
#   'website_url': None,
#   'state': 'Minnesota',
#   'street': None},
#  {'_id': ObjectId('66178c71291b18a97039234a'),
#   'id': '4b677b60-fef1-42e2-90ef-dadc1bd7fb06',
#   'name': '14er Brewing Company',
#   'brewery_type': 'proprietor',
#   'address_1': '2801 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state_province': 'Colorado',
#   'postal_code': '80205-2235',
#   'country': 'United States',
#   'longitude': '-104.9839636',
#   'latitude': '39.7614112',
#   'phone': '7207731437',
#   'website_url': 'http://www.14erBrewing.com',
#   'state': 'Colorado',
#   'street': '2801 Walnut St'},
#  {'_id': ObjectId('66178c71291b18a97039234b'),
#   'id': '6c53984f-fac1-4ea7-9c44-44e25897c71a',
#   'name': '14th Star Brewing',
#   'brewery_type': 'micro',
#   'address_1': '133 N Main St Ste 7',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Saint Albans',
#   'state_province': 'Vermont',
#   'postal_code': '05478-1735',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '8025285988',
#   'website_url': 'http://www.14thstarbrewing.com',
#   'state': 'Vermont',
#   'street': '133 N Main St Ste 7'},
#  {'_id': ObjectId('66178c71291b18a97039234c'),
#   'id': '85192a9c-58a4-48c3-bd9d-496d09d22aa3',
#   'name': '16 Lots Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '753 Reading Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mason',
#   'state_province': 'Ohio',
#   'postal_code': '45040-1303',
#   'country': 'United States',
#   'longitude': '-84.3183801',
#   'latitude': '39.3545967',
#   'phone': '5134863672',
#   'website_url': 'http://www.16lots.com',
#   'state': 'Ohio',
#   'street': '753 Reading Rd'},
#  {'_id': ObjectId('66178c71291b18a97039234d'),
#   'id': '284b44f8-6ccb-4cd6-8d06-f2ad882a47c3',
#   'name': '16 Mile Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '413 S Bedford St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Georgetown',
#   'state_province': 'Delaware',
#   'postal_code': '19947-1849',
#   'country': 'United States',
#   'longitude': '-75.37816436',
#   'latitude': '38.6788938',
#   'phone': '3022538816',
#   'website_url': 'http://www.16milebrewery.com',
#   'state': 'Delaware',
#   'street': '413 S Bedford St'},
#  {'_id': ObjectId('66178c71291b18a97039234e'),
#   'id': 'ee6d39c6-092f-4623-8099-5b8643f70dbe',
#   'name': '16 Stone Brewpub',
#   'brewery_type': 'brewpub',
#   'address_1': '9542 Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Holland Patent',
#   'state_province': 'New York',
#   'postal_code': '13354',
#   'country': 'United States',
#   'longitude': '-75.2565195',
#   'latitude': '43.24211175',
#   'phone': '3158658500',
#   'website_url': 'http://www.16stonebrewpub.com',
#   'state': 'New York',
#   'street': '9542 Main St'},
#  {'_id': ObjectId('66178c71291b18a97039234f'),
#   'id': 'd35b40b0-a3ff-4878-a6ee-9caa2149b521',
#   'name': '1623 Brewing CO, llc',
#   'brewery_type': 'contract',
#   'address_1': '1146 colonel Joshua Ct',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Westminister',
#   'state_province': 'Maryland',
#   'postal_code': '21157',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': None,
#   'website_url': None,
#   'state': 'Maryland',
#   'street': '1146 colonel Joshua Ct'},
#  {'_id': ObjectId('66178c71291b18a970392350'),
#   'id': '84bd3b3c-bd2d-4e07-bc31-b43a8c8ebf4c',
#   'name': '1717 Brewing Co',
#   'brewery_type': 'micro',
#   'address_1': '322 E Court Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Des Moines',
#   'state_province': 'Iowa',
#   'postal_code': '50309-2015',
#   'country': 'United States',
#   'longitude': '-93.6120353',
#   'latitude': '41.5872267',
#   'phone': '5152437868',
#   'website_url': 'http://1717brewing.com',
#   'state': 'Iowa',
#   'street': '322 E Court Ave'},
#  {'_id': ObjectId('66178c71291b18a970392351'),
#   'id': 'f41a0c47-ba9b-4547-bfed-fcbefe0fc74b',
#   'name': '1718 Ocracoke Brewing',
#   'brewery_type': 'brewpub',
#   'address_1': '1129 Irvin Garrish Hwy',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Ocracoke',
#   'state_province': 'North Carolina',
#   'postal_code': '27960',
#   'country': 'United States',
#   'longitude': '-75.97176063',
#   'latitude': '35.10715368',
#   'phone': '2529282337',
#   'website_url': 'http://www.ocracokebrewing.com',
#   'state': 'North Carolina',
#   'street': '1129 Irvin Garrish Hwy'},
#  {'_id': ObjectId('66178c71291b18a970392352'),
#   'id': '84d621c4-81a5-44e6-aca7-1566c2e67cc0',
#   'name': '1781 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '11109 Plank Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Spotsylvania',
#   'state_province': 'Virginia',
#   'postal_code': '22553-4258',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '5408412598',
#   'website_url': None,
#   'state': 'Virginia',
#   'street': '11109 Plank Rd'},
#  {'_id': ObjectId('66178c71291b18a970392353'),
#   'id': '896f26a1-d80e-4790-9287-026a86c1799d',
#   'name': '180 and Tapped',
#   'brewery_type': 'micro',
#   'address_1': '2010 A State Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Coraopolis',
#   'state_province': 'Pennsylvania',
#   'postal_code': '15108',
#   'country': 'United States',
#   'longitude': '-80.15020356',
#   'latitude': '40.50984957',
#   'phone': '4127375273',
#   'website_url': 'http://www.180andtapped.com',
#   'state': 'Pennsylvania',
#   'street': '2010 A State Ave'},
#  {'_id': ObjectId('66178c71291b18a970392354'),
#   'id': '46839a79-b7bf-4733-b91b-ce116d062a57',
#   'name': '1817 Brewery',
#   'brewery_type': 'micro',
#   'address_1': '100 B South Olive St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'okolona',
#   'state_province': 'Mississippi',
#   'postal_code': '38860',
#   'country': 'United States',
#   'longitude': '-88.750264',
#   'latitude': '34.001703',
#   'phone': '6623055907',
#   'website_url': None,
#   'state': 'Mississippi',
#   'street': '100 B South Olive St'},
#  {'_id': ObjectId('66178c71291b18a970392355'),
#   'id': '1a1b2165-73ed-40aa-b89b-56794d140f22',
#   'name': '1840 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '342 E Ward St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Milwaukee',
#   'state_province': 'Wisconsin',
#   'postal_code': '53207-1348',
#   'country': 'United States',
#   'longitude': '-87.90606942',
#   'latitude': '43.00436242',
#   'phone': '4142364056',
#   'website_url': 'http://www.1840brewing.com',
#   'state': 'Wisconsin',
#   'street': '342 E Ward St'},
#  {'_id': ObjectId('66178c71291b18a970392356'),
#   'id': 'fe6b9893-b93e-43d5-a9f6-3e0c89a3f13c',
#   'name': '1850 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mariposa',
#   'state_province': 'California',
#   'postal_code': '95338',
#   'country': 'United States',
#   'longitude': '-119.9036592',
#   'latitude': '37.570148',
#   'phone': None,
#   'website_url': 'http://www.1850restaurant.com',
#   'state': 'California',
#   'street': None},
#  {'_id': ObjectId('66178c71291b18a970392357'),
#   'id': 'b51f3cdf-60ff-4ae1-94a7-76906c7d62eb',
#   'name': '18th Street Brewery',
#   'brewery_type': 'micro',
#   'address_1': '5725 Miller Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gary',
#   'state_province': 'Indiana',
#   'postal_code': '46403-2871',
#   'country': 'United States',
#   'longitude': '-87.26887786',
#   'latitude': '41.59928343',
#   'phone': None,
#   'website_url': 'http://www.18thstreetbrewery.com',
#   'state': 'Indiana',
#   'street': '5725 Miller Ave'},
#  {'_id': ObjectId('66178c71291b18a970392358'),
#   'id': 'add7f978-942e-4d56-b209-c80837a51d69',
#   'name': '18th Street Brewery',
#   'brewery_type': 'micro',
#   'address_1': '5417 Oakley Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Hammond',
#   'state_province': 'Indiana',
#   'postal_code': '46320-1817',
#   'country': 'United States',
#   'longitude': '-87.517422',
#   'latitude': '41.61556796',
#   'phone': None,
#   'website_url': None,
#   'state': 'Indiana',
#   'street': '5417 Oakley Ave'},
#  {'_id': ObjectId('66178c71291b18a970392359'),
#   'id': 'dbde8235-2b55-4d8b-8b1c-438155abe104',
#   'name': '1905 Brewing Company',
#   'brewery_type': 'micro',
#   'address_1': '1301 S Chestnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Assumption',
#   'state_province': 'Illinois',
#   'postal_code': '62510-8504',
#   'country': 'United States',
#   'longitude': '-89.0503635',
#   'latitude': '39.5172564',
#   'phone': '2172549374',
#   'website_url': 'http://1905BrewingCompany.com',
#   'state': 'Illinois',
#   'street': '1301 S Chestnut St'},
#  {'_id': ObjectId('66178c71291b18a97039235a'),
#   'id': '4f4b5b34-d572-4dff-a18f-47e507c073e6',
#   'name': '1912 Brewing',
#   'brewery_type': 'micro',
#   'address_1': '2045 N Forbes Blvd Ste 105',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Tucson',
#   'state_province': 'Arizona',
#   'postal_code': '85745-1444',
#   'country': 'United States',
#   'longitude': '-110.9927505',
#   'latitude': '32.24673727',
#   'phone': '5202564851',
#   'website_url': 'http://www.1912brewing.com',
#   'state': 'Arizona',
#   'street': '2045 N Forbes Blvd Ste 105'},
#  ...]

# %%
# Fetching all documents in the Brewery collection, including only the "name" field and excluding the "_id" field
all_documents = records.find({}, {"name": 1, "_id": 0})

# Iterating through the documents and printing the "name" field
for document in all_documents:
    print(document)
# Out:
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}
# {'name': '(405) Brewing Co'}
# {'name': '(512) Brewing Co'}
# {'name': '1 of Us Brewing Company'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co'}
# {'name': '10 Barrel Brewing Co - Bend Pub'}
# {'name': '10 Barrel Brewing Co - Boise'}
# {'name': '10 Barrel Brewing Co - Denver'}
# {'name': '10 Torr Distilling and Brewing'}
# {'name': '10-56 Brewing Company'}
# {'name': '101 Brewery'}
# {'name': '101 North Brewing Company'}
# {'name': '105 West Brewing Co'}
# {'name': '10K Brewing'}
# {'name': '10th District Brewing Company'}
# {'name': '11 Below Brewing Company'}
# {'name': '1188 Brewing Co'}
# {'name': '12 Acres Brewing Company'}
# {'name': '12 Gates Brewing Company'}
# {'name': '12 West Brewing Company'}
# {'name': '12 West Brewing Company - Production Facility'}
# {'name': '122 West Brewing Co'}
# {'name': '127 Brewing'}
# {'name': '12Degree Brewing'}
# {'name': '12welve Eyes Brewing'}
# {'name': '13 Below Brewery'}
# {'name': '13 Stripes Brewery'}
# {'name': '13 Virtues Brewing Co'}
# {'name': '1323 R & D'}
# {'name': '14 Cannons Brewing Company'}
# {'name': '14 Lakes Brewery'}
# {'name': '14er Brewing Company'}
# {'name': '14th Star Brewing'}
# {'name': '16 Lots Brewing'}
# {'name': '16 Mile Brewing Co'}
# {'name': '16 Stone Brewpub'}
# {'name': '1623 Brewing CO, llc'}
# {'name': '1717 Brewing Co'}
# {'name': '1718 Ocracoke Brewing'}
# {'name': '1781 Brewing Company'}
# {'name': '180 and Tapped'}
# {'name': '1817 Brewery'}
# {'name': '1840 Brewing Company'}
# {'name': '1850 Brewing Company'}
# {'name': '18th Street Brewery'}
# {'name': '18th Street Brewery'}
# {'name': '1905 Brewing Company'}
# {'name': '1912 Brewing'}

# %%
# !pip install dash  
# !pip install pandas
# Out:
# Requirement already satisfied: dash in c:\users\marge\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\marge\anaconda3\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\marge\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\marge\anaconda3\lib\site-packages (from dash) (5.9.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\marge\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\marge\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\marge\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\marge\anaconda3\lib\site-packages (from dash) (6.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\marge\anaconda3\lib\site-packages (from dash) (4.7.1)
# Requirement already satisfied: requests in c:\users\marge\anaconda3\lib\site-packages (from dash) (2.31.0)
# Requirement already satisfied: retrying in c:\users\marge\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\marge\anaconda3\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: setuptools in c:\users\marge\anaconda3\lib\site-packages (from dash) (68.0.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\marge\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\marge\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\marge\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\marge\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\marge\anaconda3\lib\site-packages (from Werkzeug<3.1->dash) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\marge\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marge\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marge\anaconda3\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marge\anaconda3\lib\site-packages (from requests->dash) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marge\anaconda3\lib\site-packages (from requests->dash) (2023.7.22)
# Requirement already satisfied: six>=1.7.0 in c:\users\marge\anaconda3\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\marge\anaconda3\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: pandas in c:\users\marge\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marge\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marge\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\marge\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\marge\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\marge\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Mongodb Set up guide: https://docs.google.com/document/d/1EdvOK5_1D4ya94-N0RU5t9Rm_e2YurhU/edit?usp=sharing&ouid=118003078876393636228&rtpof=true&sd=true
import dash                                                    
from dash import html, dcc, Input, Output, State, dash_table
import pandas as pd                                             
import plotly.express as px
import pymongo   
from pymongo import MongoClient
from bson.objectid import ObjectId

# Connect to server on the cloud
client = MongoClient("mongodb+srv://margegbe:k6ewklnVWbhGuNIE@cluster123.jmfakxo.mongodb.net/breweryData?retryWrites=true&w=majority")

db = client.get_database('breweryData')
records = db.Brewery

print(db)


# Go into the database I created
db = client["breweryData"]
# Go into one of my database's collection (table)
collection = db["Brewery"]



# Define Layout of App
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash('brewery_data', external_stylesheets=external_stylesheets,
                suppress_callback_exceptions=True)
server = app.server

app.layout = html.Div([
    html.H1('Web Application connected to a Live Database', style={'textAlign': 'center'}),
    # interval activated once/week or when page refreshed
    dcc.Interval(id='interval_db', interval=86400000 * 7, n_intervals=0),
    html.Div(id='mongo-datatable', children=[]),

    html.Div([
        html.Div(id='pie-graph', className='five columns'),
        html.Div(id='hist-graph', className='six columns'),
    ], className='row'),
    dcc.Store(id='changed-cell')
])


# Display Datatable with data from Mongo database
@app.callback(Output('mongo-datatable', component_property='children'),
              Input('interval_db', component_property='n_intervals')
              )
def populate_datatable(n_intervals):
    global collection  # Declare collection as a global variable
    # Convert the Collection (table) date to a pandas DataFrame
    df = pd.DataFrame(list(collection.find()))
    # Convert id from ObjectId to string so it can be read by DataTable
    df['_id'] = df['_id'].astype(str)
    print(df.head(20))

    return [
        dash_table.DataTable(
            id='our-table',
            data=df.to_dict('records'),
            columns=[{'id': p, 'name': p, 'editable': False} if p == '_id'
                     else {'id': p, 'name': p, 'editable': True}
                     for p in df],
        ),
    ]


# store the row id and column id of the cell that was updated
app.clientside_callback(
    """
    function (input,oldinput) {
        if (oldinput != null) {
            if(JSON.stringify(input) != JSON.stringify(oldinput)) {
                for (i in Object.keys(input)) {
                    newArray = Object.values(input[i])
                    oldArray = Object.values(oldinput[i])
                    if (JSON.stringify(newArray) != JSON.stringify(oldArray)) {
                        entNew = Object.entries(input[i])
                        entOld = Object.entries(oldinput[i])
                        for (const j in entNew) {
                            if (entNew[j][1] != entOld[j][1]) {
                                changeRef = [i, entNew[j][0]] 
                                break        
                            }
                        }
                    }
                }
            }
            return changeRef
        }
    }    
    """,
    Output('changed-cell', 'data'),
    Input('our-table', 'data'),
    State('our-table', 'data_previous')
)


# Update MongoDB and create the graphs
@app.callback(
    Output("pie-graph", "children"),
    Output("hist-graph", "children"),
    Input("changed-cell", "data"),
    Input("our-table", "data"),
)
def update_d(cc, tabledata):
    if cc is None:
        # Build the Plots
        pie_fig = px.pie(tabledata, values='brewery_type', names='_id')
        hist_fig = px.histogram(tabledata, x='state', y='_id')
    else:
        print(f'changed cell: {cc}')
        print(f'Current DataTable: {tabledata}')
        x = int(cc[0])

        # update the external MongoDB
        row_id = tabledata[x]['_id']
        col_id = cc[1]
        new_cell_data = tabledata[x][col_id]
        collection.update_one({'_id': ObjectId(row_id)},
                              {"$set": {col_id: new_cell_data}})
        # Operations guide - https://docs.mongodb.com/manual/crud/#update-operations

        pie_fig = px.pie(tabledata, values='brewery_type', names='_id')
        hist_fig = px.histogram(tabledata, x='state', y='_id')

    return dcc.Graph(figure=pie_fig), dcc.Graph(figure=hist_fig)


if __name__ == '__main__':
     app.run_server(debug=False, port=8051)
# Out:
# Database(MongoClient(host=['ac-cmjyqn8-shard-00-01.jmfakxo.mongodb.net:27017', 'ac-cmjyqn8-shard-00-00.jmfakxo.mongodb.net:27017', 'ac-cmjyqn8-shard-00-02.jmfakxo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1f1qok-shard-0', tls=True), 'breweryData')
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#                          _id                                    id  \
# 0   661787ec291b18a970391f7a  9f1852da-c312-42da-9a31-097bac81c4c0
# 1   661787ec291b18a970391f7e  7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 2   661787ec291b18a970391f89  0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 3   661787ec291b18a970391f8c  06e9fffb-e820-45c9-b107-b52b51013e8f
# 4   661787ec291b18a970391f94  4b677b60-fef1-42e2-90ef-dadc1bd7fb06
# 5   661787ec291b18a970391f95  6c53984f-fac1-4ea7-9c44-44e25897c71a
# 6   661787ec291b18a970391f97  284b44f8-6ccb-4cd6-8d06-f2ad882a47c3
# 7   661787ec291b18a970391f99  d35b40b0-a3ff-4878-a6ee-9caa2149b521
# 8   661787ec291b18a970391f9b  f41a0c47-ba9b-4547-bfed-fcbefe0fc74b
# 9   661787ec291b18a970391fa0  fe6b9893-b93e-43d5-a9f6-3e0c89a3f13c
# 10  661787ec291b18a970391fa2  add7f978-942e-4d56-b209-c80837a51d69
# 11  661787ec291b18a970391f76  ef970757-fe42-416f-931d-722451f1f59c
# 12  661787ec291b18a970391f7b  ea4f30c0-bce6-416b-8904-fab4055a7362
# 13  661787ec291b18a970391f7c  1988eb86-f0a2-4674-ba04-02454efa0d31
# 14  661787ec291b18a970391f7d  1ecc330f-6275-42a5-b14e-00adbed62752
# 15  661787ec291b18a970391f81  4ffda196-dd59-44a5-9eeb-5f7fd4b58f5a
# 16  661787ec291b18a970391f82  42aa37d5-8384-4ffe-8c81-7c982eff0384
# 17  661787ec291b18a970391f84  08f78223-24f8-4b71-b381-ea19a5bd82df
# 18  661787ec291b18a970391f85  58293321-14ae-49d7-9a7b-08436c9e63a6
# 19  661787ec291b18a970391f86  e5f3e72a-fee2-4813-82cf-f2e53b439ae6
#
#                                              name brewery_type  \
# 0                 10 Barrel Brewing Co - Bend Pub        large
# 1                           10-56 Brewing Company        micro
# 2   12 West Brewing Company - Production Facility        micro
# 3                                12Degree Brewing      brewpub
# 4                            14er Brewing Company   proprietor
# 5                               14th Star Brewing        micro
# 6                              16 Mile Brewing Co        micro
# 7                            1623 Brewing CO, llc     contract
# 8                           1718 Ocracoke Brewing      brewpub
# 9                            1850 Brewing Company        micro
# 10                            18th Street Brewery        micro
# 11                           10 Barrel Brewing Co        large
# 12                   10 Barrel Brewing Co - Boise        large
# 13                  10 Barrel Brewing Co - Denver        large
# 14                 10 Torr Distilling and Brewing        micro
# 15                            105 West Brewing Co        micro
# 16                                    10K Brewing        micro
# 17                       11 Below Brewing Company        micro
# 18                                1188 Brewing Co      brewpub
# 19                       12 Acres Brewing Company        micro
#
#                  address_1 address_2 address_3          city  state_province  \
# 0         62950 NE 18th St      None      None          Bend          Oregon
# 1            400 Brown Cir      None      None          Knox         Indiana
# 2                     None      None      None          Mesa         Arizona
# 3              820 Main St      None      None    Louisville        Colorado
# 4           2801 Walnut St      None      None        Denver        Colorado
# 5      133 N Main St Ste 7      None      None  Saint Albans         Vermont
# 6         413 S Bedford St      None      None    Georgetown        Delaware
# 7   1146 colonel Joshua Ct      None      None  Westminister        Maryland
# 8   1129 Irvin Garrish Hwy      None      None      Ocracoke  North Carolina
# 9                     None      None      None      Mariposa      California
# 10         5417 Oakley Ave      None      None       Hammond         Indiana
# 11               1501 E St      None      None     San Diego      California
# 12        826 W Bannock St      None      None         Boise           Idaho
# 13          2620 Walnut St      None      None        Denver        Colorado
# 14             490 Mill St      None      None          Reno          Nevada
# 15            1043 Park St      None      None   Castle Rock        Colorado
# 16            2005 2nd Ave      None      None         Anoka       Minnesota
# 17       6820 Bourgeois Rd      None      None       Houston           Texas
# 18           141 E Main St      None      None      John Day          Oregon
# 19          Unnamed Street  Clonmore      None     Killeshin           Laois
#
#    postal_code        country     longitude     latitude         phone  \
# 0        97701  United States  -121.2809536   44.0912109    5415851007
# 1        46534  United States    -86.627954    41.289715    6308165790
# 2        85207  United States  -111.5860662    33.436188          None
# 3   80027-1865  United States  -105.1319826   39.9782443    3035791004
# 4   80205-2235  United States  -104.9839636   39.7614112    7207731437
# 5   05478-1735  United States          None         None    8025285988
# 6   19947-1849  United States  -75.37816436   38.6788938    3022538816
# 7        21157  United States          None         None          None
# 8        27960  United States  -75.97176063  35.10715368    2529282337
# 9        95338  United States  -119.9036592    37.570148          None
# 10  46320-1817  United States    -87.517422  41.61556796          None
# 11  92101-6618  United States   -117.129593    32.714813    6195782311
# 12  83702-5857  United States   -116.202929    43.618516    2083445870
# 13  80205-2231  United States  -104.9853655   39.7592508    7205738992
# 14       89502  United States  -119.7732015   39.5171702    7755307014
# 15  80109-1585  United States  -104.8667206  39.38269495    3033257321
# 16  55303-2243  United States  -93.38952559  45.19812039    7633924753
# 17  77066-3107  United States   -95.5186591   29.9515464    2814442337
# 18  97845-1210  United States  -118.9218754   44.4146563    5415751188
# 19    R93 X3X8        Ireland  -6.979343891  52.84930763  353599107299
#
#                        website_url           state                  street
# 0                             None          Oregon        62950 NE 18th St
# 1                             None         Indiana           400 Brown Cir
# 2                             None         Arizona                    None
# 3          http://www.12degree.com        Colorado             820 Main St
# 4       http://www.14erBrewing.com        Colorado          2801 Walnut St
# 5   http://www.14thstarbrewing.com         Vermont     133 N Main St Ste 7
# 6     http://www.16milebrewery.com        Delaware        413 S Bedford St
# 7                             None        Maryland  1146 colonel Joshua Ct
# 8   http://www.ocracokebrewing.com  North Carolina  1129 Irvin Garrish Hwy
# 9    http://www.1850restaurant.com      California                    None
# 10                            None         Indiana         5417 Oakley Ave
# 11             http://10barrel.com      California               1501 E St
# 12         http://www.10barrel.com           Idaho        826 W Bannock St
# 13                            None        Colorado          2620 Walnut St
# 14           http://www.10torr.com          Nevada             490 Mill St
# 15   http://www.105westbrewing.com        Colorado            1043 Park St
# 16              http://10KBrew.com       Minnesota            2005 2nd Ave
# 17   http://www.11belowbrewing.com           Texas       6820 Bourgeois Rd
# 18      http://www.1188brewing.com          Oregon           141 E Main St
# 19      https://12acresbrewing.ie/           Laois          Unnamed Street
